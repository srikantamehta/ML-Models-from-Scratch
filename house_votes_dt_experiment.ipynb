# %%
from src.data_preprocessor import DataProcessor
from data_configs.configs import *
from models.decision_tree import DecisionTree, DecisionTreeNode
from models.null_model import NullModelClassification
from src.cross_validation import CrossValidation
from src.evaluation import Evaluation
import numpy as np

config = house_votes_84_config
decision_tree = DecisionTree(config=config)
data_processor = DataProcessor(config=config)
cross_validator = CrossValidation(config=config)

# %% [markdown]
# ### Data Load and Preprocessing ###

# %%
raw_data = data_processor.load_data()

data_1 = data_processor.impute_missing_values(raw_data)

# %%
data_1
# Out:
#      Class Name handicapped-infants water-project-cost-sharing  \
# 0    republican                   n                          y
# 1    republican                   n                          y
# 2      democrat                   ?                          y
# 3      democrat                   n                          y
# 4      democrat                   y                          y
# ..          ...                 ...                        ...
# 430  republican                   n                          n
# 431    democrat                   n                          n
# 432  republican                   n                          ?
# 433  republican                   n                          n
# 434  republican                   n                          y
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   n                    y               y
# 1                                   n                    y               y
# 2                                   y                    ?               y
# 3                                   y                    n               ?
# 4                                   y                    n               y
# ..                                ...                  ...             ...
# 430                                 y                    y               y
# 431                                 y                    n               n
# 432                                 n                    y               y
# 433                                 n                    y               y
# 434                                 n                    y               y
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             y                       n
# 1                             y                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 430                           y                       n
# 431                           n                       y
# 432                           y                       n
# 433                           y                       ?
# 434                           y                       n
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           y
# 1                           n          n           n
# 2                           n          n           n
# 3                           n          n           n
# 4                           n          n           n
# ..                        ...        ...         ...
# 430                         n          y           y
# 431                         y          y           y
# 432                         n          n           n
# 433                         ?          ?           ?
# 434                         n          n           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              ?                  y                      y
# 1                              n                  y                      y
# 2                              y                  n                      y
# 3                              y                  n                      y
# 4                              y                  ?                      y
# ..                           ...                ...                    ...
# 430                            n                  y                      y
# 431                            n                  n                      n
# 432                            y                  y                      y
# 433                            n                  y                      y
# 434                            n                  y                      y
#
#     crime duty-free-exports export-administration-act-south-africa
# 0       y                 n                                      y
# 1       y                 n                                      ?
# 2       y                 n                                      n
# 3       n                 n                                      y
# 4       y                 y                                      y
# ..    ...               ...                                    ...
# 430     y                 n                                      y
# 431     n                 n                                      y
# 432     y                 n                                      y
# 433     y                 n                                      y
# 434     y                 ?                                      n
#
# [435 rows x 17 columns]

# %%
data_train, data_val = cross_validator.random_partition(data_1, random_state=42)

# %%
print(len(data_val))
# Out:
# 87

# %%
train_data = data_train.drop(columns=config['target_column'])
train_target = data_train[config['target_column']]
test_features = data_val.drop(columns=config['target_column'])
test_true_vals = data_val[config['target_column']]

decision_tree = DecisionTree(config)
decision_tree.root = decision_tree.build_classification_tree(train_data, train_target)
predictions = decision_tree.predict(test_features)

# %%
print(len(test_features))
# Out:
# 87

# %%
print(predictions.value_counts(dropna=False))
# Out:
# democrat      56
# republican    31
# dtype: int64

# %%
for column in data_train.columns:
    count = (data_val[column] == '?').sum()
    if count > 0:
        print(f"    {column}: {count}")
print()
# Out:
#     handicapped-infants: 3
#     water-project-cost-sharing: 8
#     adoption-of-the-budget-resolution: 3
#     physician-fee-freeze: 4
#     el-salvador-aid: 1
#     religious-groups-in-schools: 1
#     anti-satellite-test-ban: 2
#     aid-to-nicaraguan-contras: 1
#     mx-missile: 2
#     immigration: 2
#     synfuels-corporation-cutback: 8
#     education-spending: 3
#     superfund-right-to-sue: 2
#     crime: 2
#     duty-free-exports: 8
#     export-administration-act-south-africa: 19

# %%
def print_question_mark_counts(data, dataset_name):
    print(f"Counts of '?' in {dataset_name}:")
    for column in data.columns:
        count = (data[column] == '?').sum()
        if count > 0:
            print(f"    {column}: {count}")
    print()  # Add an empty line for better readability

for i, (train_set, test_set) in enumerate(cross_validator.cross_validation(data_train, n_splits=2, n_repeats=5, random_state=42, stratify=True)):
    train_data = train_set.drop(columns=config['target_column'])
    train_target = train_set[config['target_column']]
    test_features = test_set.drop(columns=config['target_column'])
    test_true_vals = test_set[config['target_column']]

    # Print counts of '?' for training and test sets
    print_question_mark_counts(train_data, f"Training Set {i}")
    print_question_mark_counts(test_features, f"Test Set {i}")

# %% [markdown]
# ## Decision Tree Performance ##

# %%
# Initialize lists to store scores for decision tree, pruned decision tree, and null model
dt_scores = {'zero_one_loss': [], 'f1_score': [], 'precision': [], 'recall': []}
pruned_dt_scores = {'zero_one_loss': [], 'f1_score': [], 'precision': [], 'recall': []}
null_model_scores = {'zero_one_loss': [], 'f1_score': [], 'precision': [], 'recall': []}

for i, (train_set, test_set) in enumerate(cross_validator.cross_validation(data_train, n_splits=2, n_repeats=5, random_state=42, stratify=True)):
    train_data = train_set.drop(columns=config['target_column'])
    train_target = train_set[config['target_column']]
    test_features = test_set.drop(columns=config['target_column'])
    test_true_vals = test_set[config['target_column']]

    # Decision Tree Model for classification
    decision_tree = DecisionTree(config)
    decision_tree.root = decision_tree.build_classification_tree(train_data, train_target)
    predictions = decision_tree.predict(test_features)

    # Calculate and store decision tree scores
    scores = Evaluation.calculate_classification_scores(test_true_vals, predictions)
    for key in dt_scores:
        dt_scores[key].append(scores[key])

    # Pruning the Decision Tree
    decision_tree.prune(decision_tree.root, data_val)  # Ensure data_val is correctly defined as your validation set
    pruned_predictions = decision_tree.predict(test_features)

    # Calculate and store pruned decision tree scores
    pruned_scores = Evaluation.calculate_classification_scores(test_true_vals, pruned_predictions)
    for key in pruned_dt_scores:
        pruned_dt_scores[key].append(pruned_scores[key])

    # Null Model for classification
    null_model = NullModelClassification(config=config)
    null_model_prediction = null_model.naive_classifier(test_set)

    # Calculate and store null model scores
    null_scores = Evaluation.calculate_classification_scores(test_true_vals, null_model_prediction)
    for key in null_model_scores:
        null_model_scores[key].append(null_scores[key])

# Calculate average scores for each model
average_dt_scores = {metric: np.mean(values) for metric, values in dt_scores.items()}
average_pruned_dt_scores = {metric: np.mean(values) for metric, values in pruned_dt_scores.items()}
average_null_model_scores = {metric: np.mean(values) for metric, values in null_model_scores.items()}

# Print average scores
print("Average Decision Tree Scores:")
for metric, avg_score in average_dt_scores.items():
    print(f"{metric}: {avg_score}")

print("\nAverage Pruned Decision Tree Scores:")
for metric, avg_score in average_pruned_dt_scores.items():
    print(f"{metric}: {avg_score}")

print("\nAverage Null Model Scores:")
for metric, avg_score in average_null_model_scores.items():
    print(f"{metric}: {avg_score}")
# Out:
#     handicapped-infants: 7
#
#     water-project-cost-sharing: 20
#
#     adoption-of-the-budget-resolution: 4
#
#     physician-fee-freeze: 4
#
#     el-salvador-aid: 9
#
#     religious-groups-in-schools: 8
#
#     anti-satellite-test-ban: 10
#
#     aid-to-nicaraguan-contras: 9
#
#     mx-missile: 10
#
#     immigration: 5
#
#     synfuels-corporation-cutback: 11
#
#     education-spending: 15
#
#     superfund-right-to-sue: 10
#
#     crime: 9
#
#     duty-free-exports: 10
#
#     export-administration-act-south-africa: 46
#
# Warning: Unseen category '?' for feature 'adoption-of-the-budget-resolution' at depth 2
# Warning: Unseen category 'y' for feature 'water-project-cost-sharing' at depth 3
# Warning: Unseen category 'y' for feature 'water-project-cost-sharing' at depth 3
# Warning: Unseen category 'y' for feature 'anti-satellite-test-ban' at depth 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-57603671e491> in <module>
#      22
#      23     # Calculate and store decision tree scores
# ---> 24     scores = Evaluation.calculate_classification_scores(test_true_vals, predictions)
#      25     for key in dt_scores:
#      26         dt_scores[key].append(scores[key])
#
# c:\Users\Srikanta\Documents\Intro to Machine Learning\programming_assignment_1\src\evaluation.py in calculate_classification_scores(y_true, y_pred)
#      16         scores = {
#      17             'zero_one_loss': Evaluation.zero_one_loss(y_true, y_pred),
# ---> 18             'f1_score': Evaluation.f1_score(y_true, y_pred),
#      19             'precision': Evaluation.precision(y_true, y_pred),
#      20             'recall': Evaluation.recall(y_true, y_pred)
#
# c:\Users\Srikanta\Documents\Intro to Machine Learning\programming_assignment_1\src\evaluation.py in f1_score(y_true, y_pred)
#      99         :return: The weighted average F1 score.
#     100         """
# --> 101         return f1_score(y_true, y_pred, average='weighted')
#     102
#     103     @staticmethod
#
# c:\Users\Srikanta\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\_param_validation.py in wrapper(*args, **kwargs)
#     211                     )
#     212                 ):
# --> 213                     return func(*args, **kwargs)
#     214             except InvalidParameterError as e:
#     215                 # When the function is just a wrapper around an estimator, we allow
#
# c:\Users\Srikanta\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1269     array([0.66666667, 1.        , 0.66666667])
#    1270     """
# -> 1271     return fbeta_score(
#    1272         y_true,
#    1273         y_pred,
#
# c:\Users\Srikanta\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\_param_validation.py in wrapper(*args, **kwargs)
#     184             global_skip_validation = get_config()["skip_parameter_validation"]
#     185             if global_skip_validation:
# --> 186                 return func(*args, **kwargs)
#     187
#     188             func_sig = signature(func)
#
# c:\Users\Srikanta\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1461     """
#    1462
# -> 1463     _, _, f, _ = precision_recall_fscore_support(
#    1464         y_true,
#    1465         y_pred,
#
# c:\Users\Srikanta\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\_param_validation.py in wrapper(*args, **kwargs)
#     184             global_skip_validation = get_config()["skip_parameter_validation"]
#     185             if global_skip_validation:
# --> 186                 return func(*args, **kwargs)
#     187
#     188             func_sig = signature(func)
#
# c:\Users\Srikanta\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1765     """
#    1766     _check_zero_division(zero_division)
# -> 1767     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1768
#    1769     # Calculate tp_sum, pred_sum, true_sum ###
#
# c:\Users\Srikanta\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1537         raise ValueError("average has to be one of " + str(average_options))
#    1538
# -> 1539     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1540     # Convert to Python primitive type to avoid NumPy type / Python str
#    1541     # comparison. See https://github.com/numpy/numpy/issues/6784
#
# c:\Users\Srikanta\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      85     check_consistent_length(y_true, y_pred)
#      86     type_true = type_of_target(y_true, input_name="y_true")
# ---> 87     type_pred = type_of_target(y_pred, input_name="y_pred")
#      88
#      89     y_type = {type_true, type_pred}
#
# c:\Users\Srikanta\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y, input_name)
#     393     if issparse(first_row):
#     394         first_row = first_row.data
# --> 395     if xp.unique_values(y).shape[0] > 2 or (y.ndim == 2 and len(first_row) > 1):
#     396         # [1, 2, 3] or [[1., 2., 3]] or [[1, 2]]
#     397         return "multiclass" + suffix
#
# c:\Users\Srikanta\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\_array_api.py in unique_values(self, x)
#     305
#     306     def unique_values(self, x):
# --> 307         return numpy.unique(x)
#     308
#     309     def concat(self, arrays, *, axis=None):
#
# c:\Users\Srikanta\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\overrides.py in unique(*args, **kwargs)
#
# c:\Users\Srikanta\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     272     ar = np.asanyarray(ar)
#     273     if axis is None:
# --> 274         ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                         equal_nan=equal_nan)
#     276         return _unpack_tuple(ret)
#
# c:\Users\Srikanta\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan)
#     334         aux = ar[perm]
#     335     else:
# --> 336         ar.sort()
#     337         aux = ar
#     338     mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'str' and 'NoneType'
